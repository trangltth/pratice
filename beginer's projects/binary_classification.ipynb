# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix

from sklearn import preprocessing
import statistics

url = 'data/sonar.all-data.csv'
data = pd.read_csv(url)

pd.set_option('display.max_rows',5)
data.dtypes
pd.set_option('display.width', 20)
data.head(10)
pd.set_option('precision', 3)
column_group = data.columns[60]
data.groupby(column_group).size()
data
# Out:
#      0.0200  \
# 0     0.045
# 1     0.026
# ..      ...
# 205   0.030
# 206   0.026
#
#      0.0371  \
# 0     0.052
# 1     0.058
# ..      ...
# 205   0.035
# 206   0.036
#
#      0.0428  \
# 0     0.084
# 1     0.110
# ..      ...
# 205   0.049
# 206   0.014
#
#      0.0207  \
# 0     0.069
# 1     0.108
# ..      ...
# 205   0.061
# 206   0.027
#
#      0.0954  \
# 0     0.118
# 1     0.097
# ..      ...
# 205   0.017
# 206   0.021
#
#      0.0986  \
# 0     0.258
# 1     0.228
# ..      ...
# 205   0.135
# 206   0.034
#
#      0.1539  \
# 0     0.216
# 1     0.243
# ..      ...
# 205   0.146
# 206   0.066
#
#      0.1601  \
# 0     0.348
# 1     0.377
# ..      ...
# 205   0.112
# 206   0.140
#
#      0.3109  \
# 0     0.334
# 1     0.560
# ..      ...
# 205   0.195
# 206   0.184
#
#      0.2111  ...  \
# 0     0.287  ...
# 1     0.619  ...
# ..      ...  ...
# 205   0.235  ...
# 206   0.235  ...
#
#      0.0027  \
# 0     0.008
# 1     0.023
# ..      ...
# 205   0.009
# 206   0.015
#
#      0.0065  \
# 0     0.009
# 1     0.017
# ..      ...
# 205   0.005
# 206   0.013
#
#      0.0159  \
# 0     0.005
# 1     0.009
# ..      ...
# 205   0.013
# 206   0.005
#
#      0.0072  \
# 0     0.009
# 1     0.018
# ..      ...
# 205   0.004
# 206   0.004
#
#      0.0167  \
# 0     0.019
# 1     0.024
# ..      ...
# 205   0.004
# 206   0.006
#
#      0.0180  \
# 0     0.014
# 1     0.032
# ..      ...
# 205   0.003
# 206   0.004
#
#      0.0084  \
# 0     0.005
# 1     0.016
# ..      ...
# 205   0.008
# 206   0.004
#
#      0.0090  \
# 0     0.005
# 1     0.009
# ..      ...
# 205   0.004
# 206   0.006
#
#      0.0032  R
# 0     0.004  R
# 1     0.008  R
# ..      ... ..
# 205   0.005  M
# 206   0.011  M
#
# [207 rows x 61 columns]

# %%
# questions: Why processing.scale not work like standard diviation

# X_train = np.array([[ 1, -1,  2],
#                     [ 2,  0,  0],
#                     [ 0,  1, -1]])
# x_scale = preprocessing.scale(X_train, with_std=True)
